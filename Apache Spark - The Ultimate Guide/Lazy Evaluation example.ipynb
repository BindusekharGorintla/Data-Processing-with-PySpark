# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("lazy Evaluation").getOrCreate()
from pyspark.sql.functions import *

# %%
data = [ (1, "Alice", 2000, "HR"), (2, "Bob", 1500, "Finance"), (3, "Charlie", 3000, "IT"), (4, "David", None, "Finance"), (5, "Eve", 2500, "HR") ] 
columns = ["id", "name", "salary", "department"]

# %%
df = spark.createDataFrame(data, columns)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th><th>department</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>2000</td><td>HR</td></tr><tr><td>2</td><td>Bob</td><td>1500</td><td>Finance</td></tr><tr><td>3</td><td>Charlie</td><td>3000</td><td>IT</td></tr><tr><td>4</td><td>David</td><td>null</td><td>Finance</td></tr><tr><td>5</td><td>Eve</td><td>2500</td><td>HR</td></tr></tbody></table></div>
