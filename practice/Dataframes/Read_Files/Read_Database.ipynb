# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Read Database").getOrCreate()

# %%
# Create DataFrame from Hive

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Read Database").enableHiveSupport.getOrCreate()

# %%
hive_df = spark.read.table("select * from db_name.table_name")
hive_df.show()

# %%
hive1_df = spark.read.parquet("/user/hive/warehouse/first_db/emp/")
hive1_df.show()

# %%
# Create DataFrame from RDBMS

# %%
jdbc_url = "jdbc:mysql://localhost:22/retail_db"
creds = {
	"username" : "root",
	"password" : "cloudera",
	"driver": "com.mysql.jdbc.Driver"
}
df = spark.read.jdbc(url=jdbc_url, properties=creds, table="emp")
